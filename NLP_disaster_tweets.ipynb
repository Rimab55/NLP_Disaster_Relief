# %% [markdown]
# Attempting to answer: Which tweets are relevant news and which ones are irrelevant
#
# https://www.figure-eight.com/data-for-everyone/

# %%
# Import data
import pandas as pd
import plotly.express as px

# %%
df = pd.read_csv('disaster-tweets-DFE.csv', encoding = "'ISO-8859-1'")

# %%
df._unit_state.value_counts()
# Out:
# finalized    10789
# golden          87
# Name: _unit_state, dtype: int64

# %%
df.head(3)
# Out:
#     _unit_id  _golden _unit_state  _trusted_judgments _last_judgment_at  \
# 0  778243823     True      golden                 156               NaN
# 1  778243824     True      golden                 152               NaN
# 2  778243825     True      golden                 137               NaN
#
#   choose_one  choose_one:confidence choose_one_gold keyword location  \
# 0   Relevant                    1.0        Relevant     NaN      NaN
# 1   Relevant                    1.0        Relevant     NaN      NaN
# 2   Relevant                    1.0        Relevant     NaN      NaN
#
#                                                 text  tweetid  userid
# 0                 Just happened a terrible car crash      1.0     NaN
# 1  Our Deeds are the Reason of this #earthquake M...     13.0     NaN
# 2  Heard about #earthquake is different cities, s...     14.0     NaN

# %%
df[['keyword','choose_one','text']]
# Out:
#       keyword    choose_one                                               text
# 0         NaN      Relevant                 Just happened a terrible car crash
# 1         NaN      Relevant  Our Deeds are the Reason of this #earthquake M...
# 2         NaN      Relevant  Heard about #earthquake is different cities, s...
# 3         NaN      Relevant  there is a forest fire at spot pond, geese are...
# 4         NaN      Relevant             Forest fire near La Ronge Sask. Canada
# 5         NaN      Relevant  All residents asked to 'shelter in place' are ...
# 6         NaN      Relevant  13,000 people receive #wildfires evacuation or...
# 7         NaN      Relevant  Just got sent this photo from Ruby #Alaska as ...
# 8         NaN      Relevant  #RockyFire Update => California Hwy. 20 closed...
# 9         NaN      Relevant           Apocalypse lighting. #Spokane #wildfires
# 10        NaN      Relevant  #flood #disaster Heavy rain causes flash flood...
# ...

# %%
# df[df['_golden'] == False]
df.keyword.value_counts()
# Out:
# hijacking                50
# crush                    50
# emergency%20plan         50
# sirens                   50
# wreck                    50
# natural%20disaster       50
# hellfire                 50
# engulfed                 50
# bleeding                 50
# electrocuted             50
# hostages                 50
# outbreak                 50
# upheaval                 50
# catastrophe              50
# blown%20up               50
# storm                    50
# lightning                50
# drowning                 50
# injuries                 50
# thunder                  50
# detonate                 50
# ruin                     50
# razed                    50
# debris                   50
# derail                   50
# structural%20failure     50
# floods                   50
# destruction              50
# trouble                  50
# rescuers                 50
#                          ..
# siren                    50
# obliterate               50
# ...

# %%
fig1 = px.histogram(df, x="choose_one", histnorm='probability density', hover_data=df.columns,
                  width=800, height=400)
fig1.show()
# Out:
# <div>
#
#
#             <div id="fec06271-62e7-471c-b1ea-bfacc93a0fcf" class="plotly-graph-div" style="height:400px; width:800px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("fec06271-62e7-471c-b1ea-bfacc93a0fcf")) {
#                     Plotly.newPlot(
#                         'fec06271-62e7-471c-b1ea-bfacc93a0fcf',
# ...

# %%
fig2 = px.histogram(df, x="choose_one_gold", histnorm='probability density', hover_data=df.columns,
                  width=800, height=400)
fig2.show()
# Out:
# <div>
#
#
#             <div id="9864c6ba-14a4-4b7e-9a11-8984eb379108" class="plotly-graph-div" style="height:400px; width:800px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9864c6ba-14a4-4b7e-9a11-8984eb379108")) {
#                     Plotly.newPlot(
#                         '9864c6ba-14a4-4b7e-9a11-8984eb379108',
# ...

# %%
df.choose_one.value_counts()
# Out:
# Not Relevant    6187
# Relevant        4673
# Can't Decide      16
# Name: choose_one, dtype: int64

# %% [markdown]
# ### Text Cleaning and Preprocessing

# %%
import re

# %%
df.text.head(20)
# Out:
# 0                    Just happened a terrible car crash
# 1     Our Deeds are the Reason of this #earthquake M...
# 2     Heard about #earthquake is different cities, s...
# 3     there is a forest fire at spot pond, geese are...
# 4                Forest fire near La Ronge Sask. Canada
# 5     All residents asked to 'shelter in place' are ...
# 6     13,000 people receive #wildfires evacuation or...
# 7     Just got sent this photo from Ruby #Alaska as ...
# 8     #RockyFire Update => California Hwy. 20 closed...
# 9              Apocalypse lighting. #Spokane #wildfires
# 10    #flood #disaster Heavy rain causes flash flood...
# 11        Typhoon Soudelor kills 28 in China and Taiwan
# 12                   We're shaking...It's an earthquake
# 13    I'm on top of the hill and I can see a fire in...
# 14    There's an emergency evacuation happening now ...
# 15    I'm afraid that the tornado is coming to our a...
# 16          Three people died from the heat wave so far
# ...

# %%
def clean_tweet(tweet):
    """Function to clean text in tweets"""
    
    # Remove special characters
    
    
    # Lower case
# Out:
#   File "<ipython-input-48-c066aeaa536a>", line 1
#     def clean_tweet(tweet):
#                            ^
# SyntaxError: unexpected EOF while parsing
